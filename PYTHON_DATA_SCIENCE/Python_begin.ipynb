# %%
first_name = "aayush"
last_name = "pateriya"
print("the fullname of the student is {}{}".format(first_name,last_name))
# Out:
# the fullname of the student is aayushpateriya

# %%
first_name = "aayush"
last_name = "pateriya"
result = print("the fullname is {}{}".format(first_name,last_name))
# Out:
# the fullname is aayushpateriya

# %%
print(first_name.isdigit())
result = print("fullname is {}{}".format(first_name,last_name))
print(result)

# %%
# List : 
## List is the the data structure in python that is mutable , or changeable  ,ordered sequence of elements , Each element or values 
## that is inside of a list is called a item . Just as string is defined  as characters between quotes,list are defined by having 
## values betweeen square brackets ...

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False
