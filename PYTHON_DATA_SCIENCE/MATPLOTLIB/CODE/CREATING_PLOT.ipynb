# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import random
from io import StringIO ,BytesIO

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.scatter(x, y, c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Scatter Graph')
plt.show()  # This line ensures the plot displays

# %%
a = [12,23,34,45,56,67,78,89,90]
b = [90,89,78,67,56,45,34,23,12]

# Scatter chart 
plt.scatter(x,y,c='g')
plt.plot(x,y,'r*--',linestyle='dashed',linewidth=2,markersize=14)   # plt.plot(x,y,'ro--', linestyle='dashed',linewidth=2,markersize=12)
plt.title('Example 2')
plt.xlabel('A axis')
plt.ylabel('B axis')
plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_2924\1155321804.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r*--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot(x,y,'r*--',linestyle='dashed',linewidth=2,markersize=14)   # plt.plot(x,y,'ro--', linestyle='dashed',linewidth=2,markersize=12)

# %%
# # Creating Subplots  : 
plt.subplot(2,2,1)
plt.plot(x,y,'r')
