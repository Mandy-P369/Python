# %% [markdown]
# # Delete or Drop or Pop Columns

# %%
import pandas as pd
import numpy as np
import random
from io import StringIO ,BytesIO

# %%
 data = pd.read_csv(r'C:\PANDA_FILES\EMPLOYEE_DATA_PANDA.csv', usecols=['first_name'	,'last_name',	'salary',	'age',
                                                                       'monthlybonus','annualbasicpay',
                                                                       'annualbonus','tax','deduction',
                                                                       'annualfinalpay','netpay','discount','joining_date'])
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
backup = data.copy()
backup
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %% [markdown]
# ### Drop Functions

# %% [markdown]
# ##### Drop function is used to remove rows and columns from the data frame

# %%
data.drop(data.columns[[4]],axis=1,inplace = True)

# %%
data
# Out:
#     first_name   last_name    salary joining_date  annualbasicpay  \
# 0       Joshua       Ramos  39792.40   2024-05-23       783765.60
# 1        David        King  32339.87   2021-10-28       388078.44
# 2      Michael     Carlson  37731.53   2020-07-13       452778.36
# 3      Christy      Martin  38943.30   2020-05-21       467319.60
# 4     Kathleen    Mcintyre  41015.44   2022-08-24       492185.28
# ..         ...         ...       ...          ...             ...
# 995     Austin     Nichols  48184.56   2022-08-26       578214.72
# 996    Raymond     Roberts  66642.13   2022-08-20       799705.56
# 997      Nancy      Kelley  54063.49   2021-12-07       648761.88
# 998     Alyssa      Rivera  44335.70   2023-11-23       532028.40
# 999     Walter  Villanueva  65796.03   2022-09-19       789552.36
#
#      annualbonus  tax  deduction  annualfinalpay     netpay  discount
# 0       78376.56    2   15675.31       768090.29  846466.85       7.0
# ...

# %%
data.drop(data.columns[[1]],axis=1)
# Out:
#     first_name    salary joining_date  annualbasicpay  annualbonus  tax  \
# 0       Joshua  39792.40   2024-05-23       783765.60     78376.56    2
# 1        David  32339.87   2021-10-28       388078.44     38807.88    7
# 2      Michael  37731.53   2020-07-13       452778.36     45277.80    7
# 3      Christy  38943.30   2020-05-21       467319.60     46731.96    7
# 4     Kathleen  41015.44   2022-08-24       492185.28     49218.48    7
# ..         ...       ...          ...             ...          ...  ...
# 995     Austin  48184.56   2022-08-26       578214.72     57821.52    2
# 996    Raymond  66642.13   2022-08-20       799705.56     79970.52    2
# 997      Nancy  54063.49   2021-12-07       648761.88     64876.20    2
# 998     Alyssa  44335.70   2023-11-23       532028.40     53202.84    2
# 999     Walter  65796.03   2022-09-19       789552.36     78955.20    2
#
#      deduction  annualfinalpay     netpay  discount
# ...

# %%
data['age']= backup['age']
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %% [markdown]
# ### Pop Functions :

# %%
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
# Code to check the number of records inside the table 
len(data)
# Out:
# 1000

# %%
# Code to check the number of columns in the table 
num_columns = data.shape[1]
print(num_columns)
# Out:
# 13

# %%
data['age'] = backup['age']
data
# Out:
#     first_name   last_name    salary joining_date  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23       6531.38
# 1        David        King  32339.87   2021-10-28       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13       3773.15
# 3      Christy      Martin  38943.30   2020-05-21       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24       4101.54
# ..         ...         ...       ...          ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# 0         783765.60     78376.56    2   15675.31       768090.29  846466.85
# ...

# %%
# Out:
#     first_name   last_name    salary joining_date  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23       6531.38
# 1        David        King  32339.87   2021-10-28       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13       3773.15
# 3      Christy      Martin  38943.30   2020-05-21       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24       4101.54
# ..         ...         ...       ...          ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# 0         783765.60     78376.56    2   15675.31       768090.29  846466.85
# ...

# %%
data.pop('last_name')
# Out:
# 0           Ramos
# 1            King
# 2         Carlson
# 3          Martin
# 4        Mcintyre
#           ...
# 995       Nichols
# 996       Roberts
# 997        Kelley
# 998        Rivera
# 999    Villanueva
# Name: last_name, Length: 1000, dtype: object

# %%
data
# Out:
#     first_name    salary joining_date  monthlybonus  annualbasicpay  \
# 0       Joshua  39792.40   2024-05-23       6531.38       783765.60
# 1        David  32339.87   2021-10-28       3233.99       388078.44
# 2      Michael  37731.53   2020-07-13       3773.15       452778.36
# 3      Christy  38943.30   2020-05-21       3894.33       467319.60
# 4     Kathleen  41015.44   2022-08-24       4101.54       492185.28
# ..         ...       ...          ...           ...             ...
# 995     Austin  48184.56   2022-08-26       4818.46       578214.72
# 996    Raymond  66642.13   2022-08-20       6664.21       799705.56
# 997      Nancy  54063.49   2021-12-07       5406.35       648761.88
# 998     Alyssa  44335.70   2023-11-23       4433.57       532028.40
# 999     Walter  65796.03   2022-09-19       6579.60       789552.36
#
#      annualbonus  tax  deduction  annualfinalpay     netpay  discount  age
# 0       78376.56    2   15675.31       768090.29  846466.85       7.0   42
# ...

# %%
# Way to get back the popped up column from the table .....
data['last_name'] = backup['last_name']

# %%
data
# Out:
#     first_name    salary joining_date  monthlybonus  annualbasicpay  \
# 0       Joshua  39792.40   2024-05-23       6531.38       783765.60
# 1        David  32339.87   2021-10-28       3233.99       388078.44
# 2      Michael  37731.53   2020-07-13       3773.15       452778.36
# 3      Christy  38943.30   2020-05-21       3894.33       467319.60
# 4     Kathleen  41015.44   2022-08-24       4101.54       492185.28
# ..         ...       ...          ...           ...             ...
# 995     Austin  48184.56   2022-08-26       4818.46       578214.72
# 996    Raymond  66642.13   2022-08-20       6664.21       799705.56
# 997      Nancy  54063.49   2021-12-07       5406.35       648761.88
# 998     Alyssa  44335.70   2023-11-23       4433.57       532028.40
# 999     Walter  65796.03   2022-09-19       6579.60       789552.36
#
#      annualbonus  tax  deduction  annualfinalpay     netpay  discount  age  \
# ...

# %%
columns_remove = ['first_name','last_name']
removed_columns = {}
for i in columns_remove :
    removed_columns[i] = data.pop(i)

data
# Out:
#        salary joining_date  monthlybonus  annualbasicpay  annualbonus  tax  \
# 0    39792.40   2024-05-23       6531.38       783765.60     78376.56    2
# 1    32339.87   2021-10-28       3233.99       388078.44     38807.88    7
# 2    37731.53   2020-07-13       3773.15       452778.36     45277.80    7
# 3    38943.30   2020-05-21       3894.33       467319.60     46731.96    7
# 4    41015.44   2022-08-24       4101.54       492185.28     49218.48    7
# ..        ...          ...           ...             ...          ...  ...
# 995  48184.56   2022-08-26       4818.46       578214.72     57821.52    2
# 996  66642.13   2022-08-20       6664.21       799705.56     79970.52    2
# 997  54063.49   2021-12-07       5406.35       648761.88     64876.20    2
# 998  44335.70   2023-11-23       4433.57       532028.40     53202.84    2
# 999  65796.03   2022-09-19       6579.60       789552.36     78955.20    2
#
#      deduction  annualfinalpay     netpay  discount  age
# ...

# %%
data_retrieve = ['first_name','last_name']
for i in data_retrieve:
    data[i] = backup[i]

# %%
data
# Out:
#        salary joining_date  monthlybonus  annualbasicpay  annualbonus  tax  \
# 0    39792.40   2024-05-23       6531.38       783765.60     78376.56    2
# 1    32339.87   2021-10-28       3233.99       388078.44     38807.88    7
# 2    37731.53   2020-07-13       3773.15       452778.36     45277.80    7
# 3    38943.30   2020-05-21       3894.33       467319.60     46731.96    7
# 4    41015.44   2022-08-24       4101.54       492185.28     49218.48    7
# ..        ...          ...           ...             ...          ...  ...
# 995  48184.56   2022-08-26       4818.46       578214.72     57821.52    2
# 996  66642.13   2022-08-20       6664.21       799705.56     79970.52    2
# 997  54063.49   2021-12-07       5406.35       648761.88     64876.20    2
# 998  44335.70   2023-11-23       4433.57       532028.40     53202.84    2
# 999  65796.03   2022-09-19       6579.60       789552.36     78955.20    2
#
# ...

# %% [markdown]
# #### Delete Function

# %%
del data['salary']

# %%
data
# Out:
#     joining_date  monthlybonus  annualbasicpay  annualbonus  tax  deduction  \
# 0     2024-05-23       6531.38       783765.60     78376.56    2   15675.31
# 1     2021-10-28       3233.99       388078.44     38807.88    7   27165.49
# 2     2020-07-13       3773.15       452778.36     45277.80    7   31694.49
# 3     2020-05-21       3894.33       467319.60     46731.96    7   32712.37
# 4     2022-08-24       4101.54       492185.28     49218.48    7   34452.97
# ..           ...           ...             ...          ...  ...        ...
# 995   2022-08-26       4818.46       578214.72     57821.52    2   11564.29
# 996   2022-08-20       6664.21       799705.56     79970.52    2   15994.11
# 997   2021-12-07       5406.35       648761.88     64876.20    2   12975.24
# 998   2023-11-23       4433.57       532028.40     53202.84    2   10640.57
# 999   2022-09-19       6579.60       789552.36     78955.20    2   15791.05
#
# ...

# %%
data['salary'] = backup['salary']
data
# Out:
#     joining_date  monthlybonus  annualbasicpay  annualbonus  tax  deduction  \
# 0     2024-05-23       6531.38       783765.60     78376.56    2   15675.31
# 1     2021-10-28       3233.99       388078.44     38807.88    7   27165.49
# 2     2020-07-13       3773.15       452778.36     45277.80    7   31694.49
# 3     2020-05-21       3894.33       467319.60     46731.96    7   32712.37
# 4     2022-08-24       4101.54       492185.28     49218.48    7   34452.97
# ..           ...           ...             ...          ...  ...        ...
# 995   2022-08-26       4818.46       578214.72     57821.52    2   11564.29
# 996   2022-08-20       6664.21       799705.56     79970.52    2   15994.11
# 997   2021-12-07       5406.35       648761.88     64876.20    2   12975.24
# 998   2023-11-23       4433.57       532028.40     53202.84    2   10640.57
# 999   2022-09-19       6579.60       789552.36     78955.20    2   15791.05
#
# ...

# %%
data
# Out:
#     joining_date  monthlybonus  annualbasicpay  annualbonus  tax  deduction  \
# 0     2024-05-23       6531.38       783765.60     78376.56    2   15675.31
# 1     2021-10-28       3233.99       388078.44     38807.88    7   27165.49
# 2     2020-07-13       3773.15       452778.36     45277.80    7   31694.49
# 3     2020-05-21       3894.33       467319.60     46731.96    7   32712.37
# 4     2022-08-24       4101.54       492185.28     49218.48    7   34452.97
# ..           ...           ...             ...          ...  ...        ...
# 995   2022-08-26       4818.46       578214.72     57821.52    2   11564.29
# 996   2022-08-20       6664.21       799705.56     79970.52    2   15994.11
# 997   2021-12-07       5406.35       648761.88     64876.20    2   12975.24
# 998   2023-11-23       4433.57       532028.40     53202.84    2   10640.57
# 999   2022-09-19       6579.60       789552.36     78955.20    2   15791.05
#
# ...
