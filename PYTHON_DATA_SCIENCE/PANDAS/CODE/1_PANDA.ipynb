# %% [markdown]
# ## Pandas :
# #### Pandas is open source ,BSD Licensing library providing high performance , easy to use data
# #### structures and data analysis tools for the Python Programming Language

# %%
# Step to import pandas 
import pandas as pd 
import numpy  as np

# %%
# Dataframe  
# A 2D data structure in Pandas with labeled axes 
# (rows and columns) that can hold different data types (integer, float, string, etc.) in each column.
df = pd.DataFrame(np.arange(40,90).reshape(10,5),
index=['row1','row2','row3','row4','row5','row6','row7','row8','row9','row10'],
columns=['marks1','marks2','marks3','marks4','marks5'])

df.head()
df.tail()

# %%
print(df)
# Out:
#        marks1  marks2  marks3  marks4  marks5
# row1       40      41      42      43      44
# row2       45      46      47      48      49
# row3       50      51      52      53      54
# row4       55      56      57      58      59
# row5       60      61      62      63      64
# row6       65      66      67      68      69
# row7       70      71      72      73      74
# row8       75      76      77      78      79
# row9       80      81      82      83      84
# row10      85      86      87      88      89

# %%
df.to_csv('Panda_text')

# %%
# Accessing the elements 
# 1 . loc
# 2 . iloc
df.loc['row1']
# Out:
# marks1    40
# marks2    41
# marks3    42
# marks4    43
# marks5    44
# Name: row1, dtype: int64

# %%
df.loc['row2']
# Out:
# marks1    45
# marks2    46
# marks3    47
# marks4    48
# marks5    49
# Name: row2, dtype: int64

# %%
df.loc['row3']
# Out:
# marks1    50
# marks2    51
# marks3    52
# marks4    53
# marks5    54
# Name: row3, dtype: int64

# %%
df.loc['row4']
# Out:
# marks1    55
# marks2    56
# marks3    57
# marks4    58
# marks5    59
# Name: row4, dtype: int64

# %%
df.iloc[:,:]
# Out:
#        marks1  marks2  marks3  marks4  marks5
# row1       40      41      42      43      44
# row2       45      46      47      48      49
# row3       50      51      52      53      54
# row4       55      56      57      58      59
# row5       60      61      62      63      64
# row6       65      66      67      68      69
# row7       70      71      72      73      74
# row8       75      76      77      78      79
# row9       80      81      82      83      84
# row10      85      86      87      88      89

# %%
#Here we want to retrieve the rows between 4 and 6 and columns between 1 and 3.....
df.iloc[4:7,1:3]
# Out:
#       marks2  marks3
# row5      61      62
# row6      66      67
# row7      71      72

# %%
# Here we want to retrieve the rows between 3 and 4 , columns between 1 and 5.
df.iloc[3:4,1:5]
# Out:
#       marks2  marks3  marks4  marks5
# row4      56      57      58      59

# %%
type(df.loc['row4'])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[0:5,2:5])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[2:6,3:]
# Out:
#       marks4  marks5
# row3      53      54
# row4      58      59
# row5      63      64
# row6      68      69

# %%
df.iloc[2:5,0:4].values
# Out:
# array([[50, 51, 52, 53],
#        [55, 56, 57, 58],
#        [60, 61, 62, 63]])

# %%
df.iloc[1:5,2:5].values.shape
# Out:
# (4, 3)

# %%
df['marks2'].value_counts()
# Out:
# marks2
# 41    1
# 46    1
# 51    1
# 56    1
# 61    1
# 66    1
# 71    1
# 76    1
# 81    1
# 86    1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# marks1    0
# marks2    0
# marks3    0
# marks4    0
# marks5    0
# dtype: int64

# %%
df['marks1'].unique()
# Out:
# array([40, 45, 50, 55, 60, 65, 70, 75, 80, 85])

# %%
df['marks4'].unique()
# Out:
# array([43, 48, 53, 58, 63, 68, 73, 78, 83, 88])

# %%
df['marks5'].unique()
# Out:
# array([44, 49, 54, 59, 64, 69, 74, 79, 84, 89])
