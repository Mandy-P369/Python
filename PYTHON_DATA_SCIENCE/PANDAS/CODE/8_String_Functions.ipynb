# %%
import pandas as pd 
import numpy as np
import random
from io import StringIO,BytesIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[178], line 4
#       2 import numpy as np
#       3 import random
# ----> 4 import table
#       5 from io import StringIO,BytesIO
#
# ModuleNotFoundError: No module named 'table'

# %%
 data = pd.read_csv(r'C:\PANDA_FILES\EMPLOYEE_DATA_PANDA.csv', usecols=['first_name'	,'last_name',	'salary',	'age',
                                                                       'monthlybonus','annualbasicpay',
                                                                       'annualbonus','tax','deduction',
                                                                       'annualfinalpay','netpay','discount','joining_date'])

# %%
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data.head()
# Out:
#   first_name last_name    salary joining_date  age  monthlybonus  \
# 0     Joshua     Ramos  39792.40   2024-05-23   42       6531.38
# 1      David      King  32339.87   2021-10-28   39       3233.99
# 2    Michael   Carlson  37731.53   2020-07-13   36       3773.15
# 3    Christy    Martin  38943.30   2020-05-21   28       3894.33
# 4   Kathleen  Mcintyre  41015.44   2022-08-24   46       4101.54
#
#    annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# 0       783765.60     78376.56    2   15675.31       768090.29  846466.85
# 1       388078.44     38807.88    7   27165.49       360912.95  399720.83
# 2       452778.36     45277.80    7   31694.49       421083.87  466361.67
# 3       467319.60     46731.96    7   32712.37       434607.23  481339.19
# 4       492185.28     49218.48    7   34452.97       457732.31  506950.79
#
#    discount
# 0       7.0
# 1       7.0
# 2       7.0
# 3       7.0
# 4       7.0

# %%
data.tail()
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# 995       578214.72     57821.52    2   11564.29       566650.43  624471.95
# 996       799705.56     79970.52    2   15994.11       783711.45  863681.97
# 997       648761.88     64876.20    2   12975.24       635786.64  700662.84
# 998       532028.40     53202.84    2   10640.57       521387.83  574590.67
# 999       789552.36     78955.20    2   15791.05       773761.31  852716.51
#
#      discount
# 995       7.0
# 996       7.0
# 997       7.0
# 998       7.0
# 999       7.0

# %% [markdown]
# #### String functions :

# %%
data['first_name'].str.lower()
# Out:
# 0        joshua
# 1         david
# 2       michael
# 3       christy
# 4      kathleen
#          ...
# 995      austin
# 996     raymond
# 997       nancy
# 998      alyssa
# 999      walter
# Name: first_name, Length: 1000, dtype: object

# %%
data['last_name'].str.upper()
# Out:
# 0           RAMOS
# 1            KING
# 2         CARLSON
# 3          MARTIN
# 4        MCINTYRE
#           ...
# 995       NICHOLS
# 996       ROBERTS
# 997        KELLEY
# 998        RIVERA
# 999    VILLANUEVA
# Name: last_name, Length: 1000, dtype: object

# %%
data['fullname']=data['first_name'].str.cat(data['last_name'],sep= ' ')
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['fullname'].str.title()
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.strip()
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.contains('Ram')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: fullname, Length: 1000, dtype: bool

# %%
data['fullname'].str.endswith('os')
data['first_name'].str.endswith('y')
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999    False
# Name: first_name, Length: 1000, dtype: bool

# %%
data['New_name']=data['fullname'].str.replace('Ram','Shyam',case = False)
data['fullname'].str.replace(' ','  ')
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['joining_date'].str.extract(r'-(\d{2})$')
data['first_name']=data['fullname'].str.extract(r'^(\w+)')
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['fullname'].str.split(' ',expand=True)
data[['year','month','day']] = data['joining_date'].str.split('-',expand=True)
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['fullname'].str.capitalize()
# Out:
# 0           Joshua ramos
# 1             David king
# 2        Michael carlson
# 3         Christy martin
# 4      Kathleen mcintyre
#              ...
# 995       Austin nichols
# 996      Raymond roberts
# 997         Nancy kelley
# 998        Alyssa rivera
# 999    Walter villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.lstrip()
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.rstrip()
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['joining_date'].str.get(6)
# Out:
# 0      5
# 1      0
# 2      7
# 3      5
# 4      8
#       ..
# 995    8
# 996    8
# 997    2
# 998    1
# 999    9
# Name: joining_date, Length: 1000, dtype: object

# %%
data['fullname'].str.repeat(1)
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].tail().str.pad(20,fillchar= '*',side='right')
# Out:
# 995    Austin Nichols******
# 996    Raymond Roberts*****
# 997    Nancy Kelley********
# 998    Alyssa Rivera*******
# 999    Walter Villanueva***
# Name: fullname, dtype: object

# %%
data['fullname'].tail().str.center(20,fillchar = '*')
# Out:
# 995    ***Austin Nichols***
# 996    **Raymond Roberts***
# 997    ****Nancy Kelley****
# 998    ***Alyssa Rivera****
# 999    *Walter Villanueva**
# Name: fullname, dtype: object

# %%
data['fullname'].str.ljust(20,fillchar='*')
# Out:
# 0      Joshua Ramos********
# 1      David King**********
# 2      Michael Carlson*****
# 3      Christy Martin******
# 4      Kathleen Mcintyre***
#                ...
# 995    Austin Nichols******
# 996    Raymond Roberts*****
# 997    Nancy Kelley********
# 998    Alyssa Rivera*******
# 999    Walter Villanueva***
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.rjust(20,fillchar='_')
# Out:
# 0      ________Joshua Ramos
# 1      __________David King
# 2      _____Michael Carlson
# 3      ______Christy Martin
# 4      ___Kathleen Mcintyre
#                ...
# 995    ______Austin Nichols
# 996    _____Raymond Roberts
# 997    ________Nancy Kelley
# 998    _______Alyssa Rivera
# 999    ___Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.zfill(20)
# Out:
# 0      00000000Joshua Ramos
# 1      0000000000David King
# 2      00000Michael Carlson
# 3      000000Christy Martin
# 4      000Kathleen Mcintyre
#                ...
# 995    000000Austin Nichols
# 996    00000Raymond Roberts
# 997    00000000Nancy Kelley
# 998    0000000Alyssa Rivera
# 999    000Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.swapcase()
# Out:
# 0           jOSHUA rAMOS
# 1             dAVID kING
# 2        mICHAEL cARLSON
# 3         cHRISTY mARTIN
# 4      kATHLEEN mCINTYRE
#              ...
# 995       aUSTIN nICHOLS
# 996      rAYMOND rOBERTS
# 997         nANCY kELLEY
# 998        aLYSSA rIVERA
# 999    wALTER vILLANUEVA
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.isalpha()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: fullname, Length: 1000, dtype: bool

# %%
data['fullname'].str.isdigit()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: fullname, Length: 1000, dtype: bool

# %%
data['fullname'].str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: fullname, Length: 1000, dtype: bool

# %%
data['salary']
data['joining_date'].str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: joining_date, Length: 1000, dtype: bool

# %%
data
data['fullname'].str.isspace()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: fullname, Length: 1000, dtype: bool

# %%
data['joining_date'].str.isalnum()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: joining_date, Length: 1000, dtype: bool

# %%
data['fullname'].tail().str.islower()
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['fullname'].head().str.repeat(4)
# Out:
# 0     Joshua RamosJoshua RamosJoshua RamosJoshua Ramos
# 1             David KingDavid KingDavid KingDavid King
# 2    Michael CarlsonMichael CarlsonMichael CarlsonM...
# 3    Christy MartinChristy MartinChristy MartinChri...
# 4    Kathleen McintyreKathleen McintyreKathleen Mci...
# Name: fullname, dtype: object

# %%
data['fullname'].str.normalize(form = 'NFKC')
data['fullname'].str.normalize(form='NFD')
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.extractall(r'(\d+)')
data['fullname'].head().str.extractall(r'(\w+)')
# Out:
#                 0
#   match
# 0 0        Joshua
#   1         Ramos
# 1 0         David
#   1          King
# 2 0       Michael
#   1       Carlson
# 3 0       Christy
#   1        Martin
# 4 0      Kathleen
#   1      Mcintyre

# %%
data['fullname'].str.slice(0,3).str.cat(data['fullname'].str.slice(4,))
# Out:
# 0           Josua Ramos
# 1             Davd King
# 2        Micael Carlson
# 3         Chrsty Martin
# 4      Katleen Mcintyre
#              ...
# 995       Ausin Nichols
# 996      Rayond Roberts
# 997         Nany Kelley
# 998        Alysa Rivera
# 999    Waler Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.slice_replace(0,4,'Radhe')
# Out:
# 0           Radheua Ramos
# 1             Radhed King
# 2        Radheael Carlson
# 3         Radhesty Martin
# 4      Radheleen Mcintyre
#               ...
# 995       Radhein Nichols
# 996      Radheond Roberts
# 997         Radhey Kelley
# 998        Radhesa Rivera
# 999    Radheer Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
data['fullname'].str.wrap(20)
# Out:
# 0           Joshua Ramos
# 1             David King
# 2        Michael Carlson
# 3         Christy Martin
# 4      Kathleen Mcintyre
#              ...
# 995       Austin Nichols
# 996      Raymond Roberts
# 997         Nancy Kelley
# 998        Alyssa Rivera
# 999    Walter Villanueva
# Name: fullname, Length: 1000, dtype: object

# %%
table  = str.maketrans('Jo','Zo')
data['translated']=data['fullname'].str.translate(table)
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['fullname'],.str.partition('@')
# Out:
#                      0 1  2
# 0         Joshua Ramos
# 1           David King
# 2      Michael Carlson
# 3       Christy Martin
# 4    Kathleen Mcintyre
# ..                 ... .. ..
# 995     Austin Nichols
# 996    Raymond Roberts
# 997       Nancy Kelley
# 998      Alyssa Rivera
# 999  Walter Villanueva
#
# [1000 rows x 3 columns]
