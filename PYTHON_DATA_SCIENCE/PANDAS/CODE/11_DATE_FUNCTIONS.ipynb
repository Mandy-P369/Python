# %% [markdown]
# # Date and Time functions

# %%
import pandas as pd
import numpy as np
import random 
from io import StringIO, BytesIO

# %%
data = pd.read_csv(r'C:\PANDA_FILES\EMPLOYEE_DATA_PANDA.csv', usecols=['first_name'	,'last_name',	'salary',	'age',
                                                                       'monthlybonus','annualbasicpay',
                                                                       'annualbonus','tax','deduction',
                                                                       'annualfinalpay','netpay','discount','joining_date'])
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
data['joining_date'] = pd.to_datetime(data['joining_date'])
data
# Out:
#     first_name   last_name    salary joining_date  age  monthlybonus  \
# 0       Joshua       Ramos  39792.40   2024-05-23   42       6531.38
# 1        David        King  32339.87   2021-10-28   39       3233.99
# 2      Michael     Carlson  37731.53   2020-07-13   36       3773.15
# 3      Christy      Martin  38943.30   2020-05-21   28       3894.33
# 4     Kathleen    Mcintyre  41015.44   2022-08-24   46       4101.54
# ..         ...         ...       ...          ...  ...           ...
# 995     Austin     Nichols  48184.56   2022-08-26   22       4818.46
# 996    Raymond     Roberts  66642.13   2022-08-20   60       6664.21
# 997      Nancy      Kelley  54063.49   2021-12-07   26       5406.35
# 998     Alyssa      Rivera  44335.70   2023-11-23   46       4433.57
# 999     Walter  Villanueva  65796.03   2022-09-19   41       6579.60
#
#      annualbasicpay  annualbonus  tax  deduction  annualfinalpay     netpay  \
# ...

# %%
# Extract the date from the date ......
data['joining_date'].dt.year
# Out:
# 0      2024
# 1      2021
# 2      2020
# 3      2020
# 4      2022
#        ...
# 995    2022
# 996    2022
# 997    2021
# 998    2023
# 999    2022
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.month
# Out:
# 0       5
# 1      10
# 2       7
# 3       5
# 4       8
#        ..
# 995     8
# 996     8
# 997    12
# 998    11
# 999     9
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.day
# Out:
# 0      23
# 1      28
# 2      13
# 3      21
# 4      24
#        ..
# 995    26
# 996    20
# 997     7
# 998    23
# 999    19
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.hour
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.minute
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.weekday
# Out:
# 0      3
# 1      3
# 2      0
# 3      3
# 4      2
#       ..
# 995    4
# 996    5
# 997    1
# 998    3
# 999    0
# Name: joining_date, Length: 1000, dtype: int32

# %%
data['joining_date'].dt.date
# Out:
# 0      2024-05-23
# 1      2021-10-28
# 2      2020-07-13
# 3      2020-05-21
# 4      2022-08-24
#           ...
# 995    2022-08-26
# 996    2022-08-20
# 997    2021-12-07
# 998    2023-11-23
# 999    2022-09-19
# Name: joining_date, Length: 1000, dtype: object

# %%
data['joining_date'].dt.strftime
# Out:
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x000002D02525E270>>
