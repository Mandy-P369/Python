# %%
import json
import os

# Your JSON data (replace this with the 40-row JSON)
data =[
  {
    "team1": "India",
    "team2": "Australia",
    "winner": "India",
    "margin": "won by 18 runs",
    "ground": "Melbourne Cricket Ground",
    "matchdate": "2024-06-01",
    "scorecard": "India 227/4; Australia 209/8"
  },
  {
    "team1": "India",
    "team2": "England",
    "winner": "India",
    "margin": "won by 11 runs",
    "ground": "Wankhede Stadium, Mumbai",
    "matchdate": "2024-06-03",
    "scorecard": "India 220/5; England 209/9"
  },
  {
    "team1": "Pakistan",
    "team2": "New Zealand",
    "winner": "Pakistan",
    "margin": "won by 6 wickets",
    "ground": "Sharjah Cricket Stadium",
    "matchdate": "2024-06-05",
    "scorecard": "New Zealand 178/9; Pakistan 182/4"
  },
  {
    "team1": "Australia",
    "team2": "South Africa",
    "winner": "Australia",
    "margin": "won by 21 runs",
    "ground": "Sydney Cricket Ground",
    "matchdate": "2024-06-07",
    "scorecard": "Australia 217/5; South Africa 196/10"
  },
  {
    "team1": "England",
    "team2": "Sri Lanka",
    "winner": "England",
    "margin": "won by 27 runs",
    "ground": "Lord’s, London",
    "matchdate": "2024-06-09",
    "scorecard": "England 212/4; Sri Lanka 185/9"
  }
]


# 1️⃣ Specify folder to save
folder_path = r"C:\Users\Ayush\OneDrive\Desktop\DATA_SCIENTIST\PYTHON_DATA_SCIENCE\_MORE"# Change to your folder
os.makedirs(folder_path, exist_ok=True)  # Create folder if it doesn't exist

# 2️⃣ Save JSON
file_path = folder_path + "wc_t20_match_summary_40rows.json"
with open(file_path, "w") as f:
    json.dump(data, f, indent=2)  # indent=2 makes it readable

print(f"✅ JSON file saved at: {file_path}")
# Out:
# ✅ JSON file saved at: C:\Users\Ayush\OneDrive\Desktop\DATA_SCIENTIST\PYTHON_DATA_SCIENCE\_MOREwc_t20_match_summary_40rows.json

# %%
import json
with open('C:\JSON\wc_t20_match_results.json') as f:
        data_results= json.load(f)
data_results
# Out:
# [{'team1': 'India',
#   'team2': 'Australia',
#   'winner': 'India',
#   'margin': 'won by 18 runs',
#   'ground': 'Melbourne Cricket Ground',
#   'matchdate': '2024-06-01',
#   'scorecard': 'India 227/4; Australia 209/8'},
#  {'team1': 'India',
#   'team2': 'England',
#   'winner': 'India',
#   'margin': 'won by 11 runs',
#   'ground': 'Wankhede Stadium, Mumbai',
#   'matchdate': '2024-06-03',
#   'scorecard': 'India 220/5; England 209/9'},
#  {'team1': 'Pakistan',
#   'team2': 'New Zealand',
#   'winner': 'Pakistan',
#   'margin': 'won by 6 wickets',
#   'ground': 'Sharjah Cricket Stadium',
#   'matchdate': '2024-06-05',
#   'scorecard': 'New Zealand 178/9; Pakistan 182/4'},
#  {'team1': 'Australia',
#   'team2': 'South Africa',
#   'winner': 'Australia',
#   'margin': 'won by 21 runs',
#   'ground': 'Sydney Cricket Ground',
#   'matchdate': '2024-06-07',
#   'scorecard': 'Australia 217/5; South Africa 196/10'},
#  {'team1': 'England',
#   'team2': 'Sri Lanka',
# ...

# %%
import json
import os

# Your JSON data (replace this with the 40-row JSON)
data =[
  {"match":"IND vs AUS","teamInnings":"India","battingpos":1,"batsmanName":"Rohit Sharma","dismissal":"c Smith b Starc","runs":47,"balls":36,"4s":5,"6s":2,"SR":130.56},
  {"match":"IND vs AUS","teamInnings":"India","battingpos":2,"batsmanName":"Shubman Gill","dismissal":"lbw b Cummins","runs":32,"balls":28,"4s":4,"6s":0,"SR":114.29},
  {"match":"IND vs AUS","teamInnings":"India","battingpos":3,"batsmanName":"Virat Kohli","dismissal":"not out","runs":89,"balls":63,"4s":8,"6s":2,"SR":141.27},
  {"match":"IND vs AUS","teamInnings":"India","battingpos":4,"batsmanName":"Shreyas Iyer","dismissal":"b Zampa","runs":21,"balls":18,"4s":2,"6s":1,"SR":116.67},
  {"match":"IND vs AUS","teamInnings":"India","battingpos":5,"batsmanName":"KL Rahul","dismissal":"c Carey b Starc","runs":38,"balls":29,"4s":3,"6s":1,"SR":131.03},

  {"match":"IND vs ENG","teamInnings":"India","battingpos":1,"batsmanName":"Rohit Sharma","dismissal":"b Wood","runs":55,"balls":41,"4s":6,"6s":2,"SR":134.15},
  {"match":"IND vs ENG","teamInnings":"India","battingpos":2,"batsmanName":"Shubman Gill","dismissal":"c Root b Woakes","runs":29,"balls":25,"4s":3,"6s":0,"SR":116.0},
  {"match":"IND vs ENG","teamInnings":"India","battingpos":3,"batsmanName":"Virat Kohli","dismissal":"c Buttler b Rashid","runs":72,"balls":50,"4s":7,"6s":1,"SR":144.0},
  {"match":"IND vs ENG","teamInnings":"India","battingpos":4,"batsmanName":"Suryakumar Yadav","dismissal":"not out","runs":46,"balls":28,"4s":4,"6s":3,"SR":164.29},
  {"match":"IND vs ENG","teamInnings":"India","battingpos":5,"batsmanName":"Hardik Pandya","dismissal":"c Stokes b Wood","runs":18,"balls":14,"4s":2,"6s":0,"SR":128.57},

  {"match":"PAK vs NZ","teamInnings":"Pakistan","battingpos":1,"batsmanName":"Babar Azam","dismissal":"c Conway b Boult","runs":61,"balls":44,"4s":5,"6s":1,"SR":138.64},
  {"match":"PAK vs NZ","teamInnings":"Pakistan","battingpos":2,"batsmanName":"Mohammad Rizwan","dismissal":"b Southee","runs":40,"balls":34,"4s":3,"6s":1,"SR":117.65},
  {"match":"PAK vs NZ","teamInnings":"Pakistan","battingpos":3,"batsmanName":"Fakhar Zaman","dismissal":"c Phillips b Santner","runs":27,"balls":19,"4s":4,"6s":1,"SR":142.11},
  {"match":"PAK vs NZ","teamInnings":"Pakistan","battingpos":4,"batsmanName":"Iftikhar Ahmed","dismissal":"not out","runs":33,"balls":22,"4s":2,"6s":2,"SR":150.0},
  {"match":"PAK vs NZ","teamInnings":"Pakistan","battingpos":5,"batsmanName":"Shadab Khan","dismissal":"run out","runs":16,"balls":12,"4s":1,"6s":1,"SR":133.33},

  {"match":"AUS vs SA","teamInnings":"Australia","battingpos":1,"batsmanName":"David Warner","dismissal":"c de Kock b Rabada","runs":68,"balls":46,"4s":7,"6s":2,"SR":147.83},
  {"match":"AUS vs SA","teamInnings":"Australia","battingpos":2,"batsmanName":"Travis Head","dismissal":"b Nortje","runs":34,"balls":22,"4s":5,"6s":1,"SR":154.55},
  {"match":"AUS vs SA","teamInnings":"Australia","battingpos":3,"batsmanName":"Steve Smith","dismissal":"c Markram b Shamsi","runs":41,"balls":35,"4s":3,"6s":0,"SR":117.14},
  {"match":"AUS vs SA","teamInnings":"Australia","battingpos":4,"batsmanName":"Glenn Maxwell","dismissal":"not out","runs":52,"balls":26,"4s":4,"6s":4,"SR":200.0},
  {"match":"AUS vs SA","teamInnings":"Australia","battingpos":5,"batsmanName":"Marcus Stoinis","dismissal":"c Miller b Rabada","runs":22,"balls":15,"4s":2,"6s":1,"SR":146.67},

  {"match":"ENG vs SL","teamInnings":"England","battingpos":1,"batsmanName":"Jos Buttler","dismissal":"c Mendis b Hasaranga","runs":49,"balls":33,"4s":5,"6s":2,"SR":148.48},
  {"match":"ENG vs SL","teamInnings":"England","battingpos":2,"batsmanName":"Jonny Bairstow","dismissal":"b Chameera","runs":35,"balls":27,"4s":4,"6s":1,"SR":129.63},
  {"match":"ENG vs SL","teamInnings":"England","battingpos":3,"batsmanName":"Joe Root","dismissal":"c Shanaka b Theekshana","runs":44,"balls":38,"4s":3,"6s":0,"SR":115.79},
  {"match":"ENG vs SL","teamInnings":"England","battingpos":4,"batsmanName":"Ben Stokes","dismissal":"not out","runs":58,"balls":34,"4s":6,"6s":2,"SR":170.59},
  {"match":"ENG vs SL","teamInnings":"England","battingpos":5,"batsmanName":"Liam Livingstone","dismissal":"c Fernando b Hasaranga","runs":26,"balls":15,"4s":2,"6s":2,"SR":173.33}
]


# 1️⃣ Specify folder to save
folder_path = r"C:\Users\Ayush\OneDrive\Desktop\DATA_SCIENTIST\PYTHON_DATA_SCIENCE\_MORE"# Change to your folder
os.makedirs(folder_path, exist_ok=True)  # Create folder if it doesn't exist

# 2️⃣ Save JSON
file_path = folder_path + "wc_t20_match_summary_40rows_another.json"
with open(file_path, "w") as f:
    json.dump(data, f, indent=2)  # indent=2 makes it readable

print(f"✅ JSON file saved at: {file_path}")
# Out:
# ✅ JSON file saved at: C:\Users\Ayush\OneDrive\Desktop\DATA_SCIENTIST\PYTHON_DATA_SCIENCE\_MOREwc_t20_match_summary_40rows_another.json

# %%
import json
with open('C:\JSON\wc_t20_match_summary.json') as f:
        data_match = json.load(f)
data_match
# Out:
# [{'match': 'IND vs AUS',
#   'teamInnings': 'India',
#   'battingpos': 1,
#   'batsmanName': 'Rohit Sharma',
#   'dismissal': 'c Smith b Starc',
#   'runs': 47,
#   'balls': 36,
#   '4s': 5,
#   '6s': 2,
#   'SR': 130.56},
#  {'match': 'IND vs AUS',
#   'teamInnings': 'India',
#   'battingpos': 2,
#   'batsmanName': 'Shubman Gill',
#   'dismissal': 'lbw b Cummins',
#   'runs': 32,
#   'balls': 28,
#   '4s': 4,
#   '6s': 0,
#   'SR': 114.29},
#  {'match': 'IND vs AUS',
#   'teamInnings': 'India',
#   'battingpos': 3,
#   'batsmanName': 'Virat Kohli',
#   'dismissal': 'not out',
#   'runs': 89,
#   'balls': 63,
#   '4s': 8,
#   '6s': 2,
#   'SR': 141.27},
#  {'match': 'IND vs AUS',
#   'teamInnings': 'India',
#   'battingpos': 4,
#   'batsmanName': 'Shreyas Iyer',
#   'dismissal': 'b Zampa',
#   'runs': 21,
#   'balls': 18,
#   '4s': 2,
#   '6s': 1,
#   'SR': 116.67},
#  {'match': 'IND vs AUS',
#   'teamInnings': 'India',
#   'battingpos': 5,
#   'batsmanName': 'KL Rahul',
# ...

# %%
df_match = pd.DataFrame(data_match)
df_match
# Out:
#          match teamInnings  battingpos       batsmanName  \
# 0   IND vs AUS       India           1      Rohit Sharma
# 1   IND vs AUS       India           2      Shubman Gill
# 2   IND vs AUS       India           3       Virat Kohli
# 3   IND vs AUS       India           4      Shreyas Iyer
# 4   IND vs AUS       India           5          KL Rahul
# 5   IND vs ENG       India           1      Rohit Sharma
# 6   IND vs ENG       India           2      Shubman Gill
# 7   IND vs ENG       India           3       Virat Kohli
# 8   IND vs ENG       India           4  Suryakumar Yadav
# 9   IND vs ENG       India           5     Hardik Pandya
# 10   PAK vs NZ    Pakistan           1        Babar Azam
# 11   PAK vs NZ    Pakistan           2   Mohammad Rizwan
# 12   PAK vs NZ    Pakistan           3      Fakhar Zaman
# 13   PAK vs NZ    Pakistan           4    Iftikhar Ahmed
# 14   PAK vs NZ    Pakistan           5       Shadab Khan
# ...

# %%
df_results = pd.DataFrame(data_results)
df_results
# Out:
#        team1         team2     winner            margin  \
# 0      India     Australia      India    won by 18 runs
# 1      India       England      India    won by 11 runs
# 2   Pakistan   New Zealand   Pakistan  won by 6 wickets
# 3  Australia  South Africa  Australia    won by 21 runs
# 4    England     Sri Lanka    England    won by 27 runs
#
#                      ground   matchdate                             scorecard
# 0  Melbourne Cricket Ground  2024-06-01          India 227/4; Australia 209/8
# 1  Wankhede Stadium, Mumbai  2024-06-03            India 220/5; England 209/9
# 2   Sharjah Cricket Stadium  2024-06-05     New Zealand 178/9; Pakistan 182/4
# 3     Sydney Cricket Ground  2024-06-07  Australia 217/5; South Africa 196/10
# 4            Lord’s, London  2024-06-09        England 212/4; Sri Lanka 185/9
